# %% [markdown]
# # Notebook to learn, practice, and experiement concepts and tools in Cymetric and python

# %% [markdown]
# Working with the cymetric package. Goals:
# * Learn about the different aspects of the data in the sqlite database
# * Learn to view different aspects of the data
# * Learn about filters that can be applied to the data
# * Learn to make plots of the data
#
# Using the example files found in github.com/cylus/cymetric/examples; mostly recreating the agent_entryexit.py
#
# Tutorial on the Cyclus website: http://fuelcycle.org/user/cymetric/tutorial_py.html

# %%
#Running cyclus from jupyter:
! rm recycle.sqlite #Cyclus won't overwrite an old output file
! cyclus recycle.xml -o recycle.sqlite # -o flag specifies an output file name
# Out:
#               :
#           .CL:CC CC             _Q     _Q  _Q_Q    _Q    _Q              _Q
#         CC;CCCCCCCC:C;         /_\)   /_\)/_/\\)  /_\)  /_\)            /_\)
#         CCCCCCCCCCCCCl       __O|/O___O|/O_OO|/O__O|/O__O|/O____________O|/O__
#      CCCCCCf     iCCCLCC     /////////////////////////////////////////////////
#      iCCCt  ;;;;;.  CCCC
#     CCCC  ;;;;;;;;;. CClL.                          c
#    CCCC ,;;       ;;: CCCC  ;                   : CCCCi
#     CCC ;;         ;;  CC   ;;:                CCC`   `C;
#   lCCC ;;              CCCC  ;;;:             :CC .;;. C;   ;    :   ;  :;;
#   CCCC ;.              CCCC    ;;;,           CC ;    ; Ci  ;    :   ;  :  ;
#    iCC :;               CC       ;;;,        ;C ;       CC  ;    :   ; .
#   CCCi ;;               CCC        ;;;.      .C ;       tf  ;    :   ;  ;.
#   CCC  ;;               CCC          ;;;;;;; fC :       lC  ;    :   ;    ;:
#    iCf ;;               CC         :;;:      tC ;       CC  ;    :   ;     ;
#   fCCC :;              LCCf      ;;;:         LC :.  ,: C   ;    ;   ; ;   ;
#   CCCC  ;;             CCCC    ;;;:           CCi `;;` CC.  ;;;; :;.;.  ; ,;
#     CCl ;;             CC    ;;;;              CCC    CCL
#    tCCC  ;;        ;; CCCL  ;;;                  tCCCCC.
#     CCCC  ;;     :;; CCCCf  ;                     ,L
#      lCCC   ;;;;;;  CCCL
#      CCCCCC  :;;  fCCCCC
#       . CCCC     CCCC .
#        .CCCCCCCCCCCCCi
#           iCCCCCLCf
#            .  C. ,
#               :
# terminate called after throwing an instance of 'cyclus::IOError'
#   what():  The file 'recycle.xml' could not be loaded.
# Aborted (core dumped)

# %%
import cymetric as cym
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pyne import nucname
from numpy import isclose
#import analysis as analysis

# %%
# Open the database
db = cym.dbopen('recycle.sqlite')
#help(cym.Evaluator)

# %%
#Command to evaluate metrics of the data base
evaler = cym.Evaluator(db)
evaler.__dict__
#cym.eval('Commissioning',db)
comm = evaler.eval('BuildSeries')
decomm = evaler.eval('DecommissionSeries')

# %% [markdown]
# Possible metrics (most of the tables in the database):
# * Materials
# * AgentEntry
# * Recipes
# * InputFiles
# * Transactions
# * Compositions
# * Decay Mode
# * TimeStepDur

# %%
decomm
# Out:
#                                    SimId  ExitTime Prototype  Count
# 0   e104c34f-5961-43ba-a8d3-8cd9b1632876       206       lwr      1
# 1   e104c34f-5961-43ba-a8d3-8cd9b1632876       207       lwr      2
# 2   e104c34f-5961-43ba-a8d3-8cd9b1632876       222       lwr      1
# 3   e104c34f-5961-43ba-a8d3-8cd9b1632876       224       lwr      1
